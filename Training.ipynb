# %%
my_name="Nabeel M"
my_age=25
favorite_number=49
is_student=False
print("Hello, My name is", my_name, "and I’m", my_age, "years old.""And my lucky number is",favorite_number,"Is this my first coding ?",is_student,)
# Out:
# Hello, My name is Nabeel M and I’m 25 years old.And my lucky number is 49 Is this my first coding ? False

# %%
x = 5
y = "5"
print(x + x)
print(y + y)
# Out:
# 10
# 55

# %%
x = "10"
y = 5
print(x * y)
# Out:
# 1010101010

# %%
print("hjhhdho448648")
# Out:
# hjhhdho448648

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

print(is_prime(5))
# Out:
# True

# %%
def fibonacci(n):
    a, b = 0, 1,53
    for _ in range(2):
        print(a, end=" ")
        a, b = b, a + b

# %% [markdown]
# def largest_of_three(a, b, c):
#     return max(a, b, c)

# %%
def is_leap_year(year):
    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)
print(is_leap_year(2028))
# Out:
# True
